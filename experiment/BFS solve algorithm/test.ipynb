# %%
from solver import solve_with_c
from pyraminx import Pyraminx, print_face


# --- TEST ---
print("\n--- TEST FINAL (C + Python) ---")
# État mélangé correspondant à un fichier existant (ex: byrg)
# Assurez-vous d'avoir converti vos fichiers avant !
test_state = "rrrrrrrrrbbbbbbbbbyyyyyyyyyggggggggg"
# Mélange manuel
c = Pyraminx(state=test_state)
c = c.up(1)       # U
c = c.right(1)    # R
scrambled = c.stringify()

scrambled = "rbrgbbbyy" + "yyybbbggg" + "gggrbbyrr" + "yryrggyrr"

print_face(scrambled)

sequence = solve_with_c(scrambled)

print(sequence)
# Out:
# --- TEST FINAL (C + Python) ---
#
# ==================================================
#        LEFT             FRONT             RIGHT
# ==================================================
#
#
#
#
#
#
#
#
#
# ==================================================
#                        BOTTOM
# ==================================================
#
# État initial (Tips corrigés): rbrgbbbyyyyybbbggggggrbbyrryryrggyrr
#
# ✅ RÉSOLU avec rygb.bin
# Temps total : 4.6170 sec
# Coups (9) : B R' B R' L B U' B U
# ['B', "R'", 'B', "R'", 'L', 'B', "U'", 'B', 'U']
